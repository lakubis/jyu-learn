# %%
from numpy.random import SeedSequence, default_rng
entropy = 52906836728959148027957190488174817840

# %%
ss = SeedSequence(entropy)
child_seeds = ss.spawn(10)
#print(child_seeds)
print([s for s in child_seeds])
streams = [default_rng(s) for s in child_seeds]
print(streams)
# Out:
# [SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(0,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(1,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(2,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(3,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(4,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(5,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(6,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(7,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(8,),
# ), SeedSequence(
#     entropy=52906836728959148027957190488174817840,
#     spawn_key=(9,),
# )]
# [Generator(PCG64) at 0x11B7E8B6180, Generator(PCG64) at 0x11B7E8B5A80, Generator(PCG64) at 0x11B7E8B5E00, Generator(PCG64) at 0x11B7E8B5EE0, Generator(PCG64) at 0x11B7E8B5D20, Generator(PCG64) at 0x11B7E8B5FC0, Generator(PCG64) at 0x11B7E8B6260, Generator(PCG64) at 0x11B7E8B6340, Generator(PCG64) at 0x11B7E8B6880, Generator(PCG64) at 0x11B7E8B6960]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
for s in streams: print(s.random(5))
# Out:
# [0.76290183 0.71805514 0.0024591  0.40761819 0.29965213]
# [0.77682229 0.03346925 0.5365725  0.0804579  0.70656282]
# [0.42773006 0.40219944 0.50305567 0.75533785 0.09025258]
# [0.30682339 0.03593333 0.3530479  0.48889276 0.16290473]
# [0.51391904 0.09281144 0.75393745 0.43352109 0.27942142]
# [0.31349458 0.05343867 0.17038458 0.72544615 0.9715868 ]
# [0.14481718 0.43824012 0.17475976 0.62203394 0.19595243]
# [0.67786537 0.79596878 0.80165955 0.75001245 0.51741944]
# [0.11047852 0.97390259 0.03007817 0.01987788 0.61791205]
# [0.23749537 0.60201809 0.96403635 0.53768631 0.28775971]

# %%
import numpy as np
import matplotlib.pyplot as plt
xs = np.random.random(10000)
ys = np.random.random(10000)

plt.scatter(xs,ys, s = .1)
